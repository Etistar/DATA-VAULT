# %% [markdown]
# # TELECHARGEMENT DU FICHIER

# %%
#Téléchargement du fichier CSV depuis GitHub
import pandas as pd

url = "https://raw.githubusercontent.com/Ejeus/EDA-Retail-Sales-Data-with-Seasonal-Trends-Marketing/main/Retail_sales.csv"
df = pd.read_csv(url)
df.to_csv("/lakehouse/default/Files/Retail_sales.csv")
#Aperçu des données
df.head()
# Out:
# StatementMeta(, 626edc61-1730-4ef7-add9-2056f08fff23, 6, Finished, Available, Finished)
#      Store ID  Product ID        Date  Units Sold  Sales Revenue (USD)  \
# 0  Spearsland    52372247  2022-01-01           9              2741.69
# 1  Spearsland    52372247  2022-01-02           7              2665.53
# 2  Spearsland    52372247  2022-01-03           1               380.79
# 3  Spearsland    52372247  2022-01-04           4              1523.16
# 4  Spearsland    52372247  2022-01-05           2               761.58
#
#    Discount Percentage  Marketing Spend (USD)             Store Location  \
# 0                   20                     81                   Tanzania
# 1                    0                      0                 Mauritania
# 2                    0                      0  Saint Pierre and Miquelon
# 3                    0                      0                  Australia
# 4                    0                      0                  Swaziland
#
# ...

# %%
print(f"""dimension du dataframe{df.shape},
types des colonnes {df.dtypes}""")
# Out:
# StatementMeta(, 626edc61-1730-4ef7-add9-2056f08fff23, 4, Finished, Available, Finished)
# dimension du dataframe(30000, 11),
# types des colonnes Store ID                  object
# Product ID                 int64
# Date                      object
# Units Sold                 int64
# Sales Revenue (USD)      float64
# Discount Percentage        int64
# Marketing Spend (USD)      int64
# Store Location            object
# Product Category          object
# Day of the Week           object
# Holiday Effect              bool
# dtype: object
